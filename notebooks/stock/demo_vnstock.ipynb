# %%
import vnstock as vns

# %%
vns.ticker_overview('TCB')
# Out:
#   exchange    shortName  industryID industryIDv2   industry industryEn
# 0     HOSE  Techcombank         289         8355  Ngân hàng      Banks  \
#
#   establishedYear  noEmployees  noShareholders  foreignPercent
# 0            1993         9757            1901           0.225  \
#
#                          website  stockRating  deltaInWeek  deltaInMonth
# 0  http://www.techcombank.com.vn          4.2        0.003         0.074  \
#
#    deltaInYear  outstandingShare  issueShare companyType ticker
# 0       -0.086            3517.2      3517.2          NH    TCB

# %%
df = vns.stock_historical_data(symbol='BID', 
                            start_date="2023-02-05", 
                            end_date='2023-04-21')

# %%
df
# Out:
#        Open     High      Low    Close   Volume TradingDate
# 0   43300.0  45000.0  42900.0  45000.0  1748181  2023-02-06
# 1   45000.0  45350.0  43700.0  43800.0  1569559  2023-02-07
# 2   43900.0  45250.0  43900.0  44500.0  1798589  2023-02-08
# 3   44500.0  45000.0  44000.0  44000.0  1185612  2023-02-09
# 4   44400.0  44550.0  42950.0  42950.0  1398920  2023-02-10
# 5   42950.0  44400.0  42950.0  44400.0  1590833  2023-02-13
# 6   44500.0  44500.0  43300.0  43400.0  1325859  2023-02-14
# 7   43150.0  44450.0  43150.0  44000.0   605202  2023-02-15
# 8   44700.0  45000.0  44000.0  45000.0  1068840  2023-02-16
# 9   45000.0  45800.0  44950.0  45800.0  1495042  2023-02-17
# 10  45800.0  47350.0  45800.0  47200.0  1511483  2023-02-20
# 11  47200.0  47300.0  46250.0  46250.0   998047  2023-02-21
# 12  45850.0  46000.0  45000.0  45000.0   995108  2023-02-22
# 13  44950.0  45550.0  43700.0  45550.0  1281017  2023-02-23
# 14  45050.0  45550.0  44400.0  44600.0   498530  2023-02-24
# ...
